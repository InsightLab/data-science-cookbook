# %% [markdown]
# # Exercício - Clustering
# ### Aluno : Joel Ribeiro - 371822
# -------

# %%
# import das bibliotecas importantes
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
# %matplotlib inline

# %%
iris = datasets.load_iris()
iris_data, rotules = [iris.get('data'), iris.get('target')]
print(iris_data)
# Out:
# [[ 5.1  3.5  1.4  0.2]
#  [ 4.9  3.   1.4  0.2]
#  [ 4.7  3.2  1.3  0.2]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.   3.6  1.4  0.2]
#  [ 5.4  3.9  1.7  0.4]
#  [ 4.6  3.4  1.4  0.3]
#  [ 5.   3.4  1.5  0.2]
#  [ 4.4  2.9  1.4  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 5.4  3.7  1.5  0.2]
#  [ 4.8  3.4  1.6  0.2]
#  [ 4.8  3.   1.4  0.1]
#  [ 4.3  3.   1.1  0.1]
#  [ 5.8  4.   1.2  0.2]
#  [ 5.7  4.4  1.5  0.4]
#  [ 5.4  3.9  1.3  0.4]
#  [ 5.1  3.5  1.4  0.3]
#  [ 5.7  3.8  1.7  0.3]
#  [ 5.1  3.8  1.5  0.3]
#  [ 5.4  3.4  1.7  0.2]
#  [ 5.1  3.7  1.5  0.4]
#  [ 4.6  3.6  1.   0.2]
#  [ 5.1  3.3  1.7  0.5]
#  [ 4.8  3.4  1.9  0.2]
#  [ 5.   3.   1.6  0.2]
#  [ 5.   3.4  1.6  0.4]
#  [ 5.2  3.5  1.5  0.2]
#  [ 5.2  3.4  1.4  0.2]
#  [ 4.7  3.2  1.6  0.2]
#  [ 4.8  3.1  1.6  0.2]
#  [ 5.4  3.4  1.5  0.4]
#  [ 5.2  4.1  1.5  0.1]
#  [ 5.5  4.2  1.4  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 5.   3.2  1.2  0.2]
#  [ 5.5  3.5  1.3  0.2]
#  [ 4.9  3.1  1.5  0.1]
#  [ 4.4  3.   1.3  0.2]
#  [ 5.1  3.4  1.5  0.2]
# ...

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(iris_data)

# %%
predictions = kmeans.predict(iris_data)

reduced_data = PCA(n_components=2).fit_transform(iris_data)

reduced_data_df = pd.DataFrame(reduced_data)
reduced_data_df[2] = predictions

# k-means clusters
fig, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=reduced_data_df[2])
plt.show()

# Original
fig, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=rotules)
plt.show()

# %%
kmeans = KMeans(n_clusters=5, random_state=0).fit(iris_data)
predictions = kmeans.predict(iris_data)

reduced_data = PCA(n_components=2).fit_transform(iris_data)

reduced_data_df = pd.DataFrame(reduced_data)
reduced_data_df[2] = predictions

# k-means clusters
fig, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=reduced_data_df[2])
plt.show()

# Original
fig, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=rotules)
plt.show()
