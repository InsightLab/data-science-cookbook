# %% [markdown]
# Exercícios
#
# 1 - Aplique os algoritmos K-means [1] e AgglomerativeClustering [2] em qualquer dataset que você desejar (recomendação: iris). Compare os resultados utilizando métricas de avaliação de clusteres (completeness e homogeneity, por exemplo) [3].
#
#     [1] http://scikit-learn.org/stable/modules/clustering.html#k-means
#
#     [2] http://scikit-learn.org/0.17/modules/clustering.html#hierarchical-clustering
#
#     [3] http://scikit-learn.org/stable/modules/clustering.html#clustering-evaluation
#
# 2 - Qual o valor de K (número de clusteres) você escolheu para a questão anterior? Desenvolva o Método do Cotovelo (não utilizar lib!) e descubra o K mais adequado. Após descobrir, aplique novamente o K-means com o K adequado.
#
#     Ajuda: atributos do k-means
#
# 3 - Após a questão 2, você aplicou o algoritmo com K apropriado. Refaça o cálculo das métricas de acordo com os resultados de clusters obtidos com a questão anterior e verifique se o resultado melhorou.

# %%
from sklearn.datasets import load_iris
from sklearn import decomposition
from sklearn import metrics
from sklearn.model_selection import train_test_split
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataset = load_iris()
X = dataset.data
y = dataset.target

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X)

# %%
# kmeans.labels_

# %%
predictions= kmeans.predict(X)
# data = decomposition.PCA(n_components=2).fit_transform(X)
data=kmeans.fit_transform(X)
data_df = pd.DataFrame(data)

# %%
# print(predictions)
# print(reduced)
# print(reduced_data_df)
data_df[2]=predictions
print(data_df)
# Out:
#             0         1  2
# 0    0.250176  4.089154  0
# 1    0.418604  4.108307  0
# 2    0.442488  4.276180  0
# 3    0.494062  4.140016  0
# 4    0.302729  4.135706  0
# 5    0.691419  3.760009  0
# 6    0.438849  4.215490  0
# 7    0.115511  4.019571  0
# 8    0.782921  4.303085  0
# 9    0.344147  4.064270  0
# 10   0.531590  3.959061  0
# 11   0.230552  4.004449  0
# 12   0.483836  4.180618  0
# 13   0.936545  4.631831  0
# 14   1.085906  4.225712  0
# 15   1.256659  4.036578  0
# 16   0.726547  4.111530  0
# 17   0.234206  4.053640  0
# 18   0.833352  3.709926  0
# 19   0.454063  4.023467  0
# 20   0.428846  3.732642  0
# 21   0.374850  3.968178  0
# 22   0.738908  4.616481  0
# 23   0.275995  3.696354  0
# 24   0.407180  3.756375  0
# 25   0.373084  3.901855  0
# 26   0.124170  3.862233  0
# 27   0.262685  3.973565  0
# 28   0.271167  4.047010  0
# 29   0.358381  4.022494  0
# ..        ...       ... ..
# 120  4.978003  1.171061  1
# 121  3.838797  0.771290  1
# 122  6.074408  2.255884  1
# 123  3.941571  0.221618  1
# 124  4.824539  1.021189  1
# 125  5.178652  1.414702  1
# 126  3.808870  0.231849  1
# 127  3.840836  0.259939  1
# 128  4.673585  0.769282  1
# 129  4.962153  1.240112  1
# 130  5.406874  1.599788  1
# 131  5.907857  2.358105  1
# 132  4.713243  0.826208  1
# 133  3.996525  0.256546  1
# 134  4.394781  0.788213  1
# 135  5.659134  1.907187  1
# 136  4.736863  1.081923  1
# 137  4.449925  0.599262  1
# 138  3.726340  0.373533  1
# 139  4.654613  0.873104  1
# 140  4.868220  1.054368  1
# 141  4.496366  0.888379  1
# 142  4.022313  0.589462  1
# 143  5.109475  1.264153  1
# 144  4.988510  1.235364  1
# 145  4.503242  0.771490  1
# 146  4.102432  0.439120  1
# 147  4.304029  0.450705  1
# 148  4.494624  0.912932  1
# 149  3.966028  0.452190  1
#
# [150 rows x 3 columns]

# %%
colors = map(lambda x: colmap[x+1], predictions)

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=reduced_data_df[2], alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(reduced_data_df[0], reduced_data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()

# %% [markdown]
# AgglomerativeClustering

# %%
from sklearn.cluster import AgglomerativeClustering

agglo_euclidean = AgglomerativeClustering(n_clusters=3, affinity="euclidean", linkage="complete").fit_predict(X)
agglo_manhattan = AgglomerativeClustering(n_clusters=3, affinity="manhattan", linkage="complete").fit_predict(X)

# Usando metodo euclidean

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=agglo_euclidean, alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()

# %%
# usando metodo manhattan
f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=agglo_manhattan, alpha=0.5, edgecolor='k')
plt.show()

f, ax = plt.subplots()
ax.scatter(data_df[0], data_df[1], c=y, alpha=0.5, edgecolor='k')
plt.show()
